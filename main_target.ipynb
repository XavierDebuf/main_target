# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
#sqfichier = open("./main_targetSpiderFoot.gexf", "r")
#print(fichier.read())
fin = open("./main_targetSpiderFoot.gexf", "rt")
fout = open("./main_target_reformat.gexf", "wt")

for line in fin:
    fout.write(line.replace('None', '-1'))

fin.close()
fout.close()

# %%
main_g = nx.read_gexf("./main_target_reformat.gexf", relabel=True)

# %%
nx.draw(main_g)
